# %%
import pandas as pd
import numpy as np 
teams = {}

def createDict():
    teams["Atlanta Hawks"] = "ATL"
    teams["Brooklyn Nets"] = "BRK"
    teams["Boston Celtics"] = "BOS"
    teams["Charlotte Hornets"] = "CHO"
    teams["Chicago Bulls"] = "CHI"
    teams["Cleveland Cavaliers"] = "CLE"
    teams["Dallas Mavericks"] = "DAL"
    teams["Denver Nuggets"] = "DEN"
    teams["Detroit Pistons"] = "DET"
    teams["Golden State Warriors"] = "GSW"
    teams["Houston Rockets"] = "HOU"
    teams["Indiana Pacers"] = "IND"
    teams["Los Angeles Clippers"] = "LAC"
    teams["Los Angeles Lakers"] = "LAL"
    teams["Memphis Grizzlies"] = "MEM"
    teams["Miami Heat"] = "MIA"
    teams["Milwaukee Bucks"] = "MIL"
    teams["Minnesota Timberwolves"] = "MIN"
    teams["New Orleans Pelicans"] = "NOP"
    teams["New York Knicks"] = "NYK"
    teams["Oklahoma City Thunder"] = "OKC"
    teams["Orlando Magic"] = "ORL"
    teams["Philadelphia 76ers"] = "PHI"
    teams["Phoenix Suns"] = "PHO"
    teams["Portland Trail Blazers"] = "POR"
    teams["Sacramento Kings"] = "SAC"
    teams["San Antonio Spurs"] = "SAS"
    teams["Toronto Raptors"] = "TOR"
    teams["Utah Jazz"] = "UTA"
    teams["Washington Wizards"] = "WAS"
    teams["Charlotte Bobcats"] = "CHA"
    teams["New Orleans Hornets"] = "NOH"
    teams["New Jersey Nets"] = "NJN"

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames)
    return result

# %%
teamPGVars = ['teamPG09', 'teamPG10', 'teamPG11' , 'teamPG12', 'teamPG13', 'teamPG14', 'teamPG15',  'teamPG16', 'teamPG17', 'teamPG18']

# %%
teamVars = ['tstats09.csv', 'tstats10.csv', 'tstats11.csv', 'tstats12.csv', 'tstats13.csv', 'tstats14.csv', 'tstats15.csv', 'tstats16.csv', 'tstats17.csv', 'tstats18.csv']

# %%
teamPG = inputData(teamPGVars, 1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-0f67ab08278e> in <module>()
# ----> 1 teamPG = inputData(teamPGVars, 1)
#
# <ipython-input-2-7a3559a8df70> in inputData(stats, n)
#       5     frames = []
#       6     for item in stats:
# ----> 7         a = pd.read_csv(item)
#       8         if n >= 0 and n <= 3:
#       9             if n == 0:  #delete first row of team rankings dataframe
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'teamPG09' does not exist

# %%
teamPGVars = ['teamPG09.csv', 'teamPG10.csv', 'teamPG11.csv' , 'teamPG12.csv', 'teamPG13.csv', 'teamPG14.csv', 'teamPG15.csv',  'teamPG16.csv', 'teamPG17.csv', 'teamPG18.csv']

# %%
teamPG = inputData(teamPGVars, 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-0f67ab08278e> in <module>()
# ----> 1 teamPG = inputData(teamPGVars, 1)
#
# <ipython-input-2-7a3559a8df70> in inputData(stats, n)
#      10                 a = a.iloc[1:, 0:5]
#      11                 a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
# ---> 12             a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
#      13         a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
#      14         if n == 0:
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-2-7a3559a8df70> in <lambda>(x)
#      10                 a = a.iloc[1:, 0:5]
#      11                 a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
# ---> 12             a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
#      13         a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
#      14         if n == 0:
#
# KeyError: ('Los Angeles Lakers*', 'occurred at index 2')

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                a['Team'] = a.apply(lambda x: s.replace('*', '') for s in a['Team'], axis = 1)
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames)
    return result
# Out:
#   File "<ipython-input-8-717d04c50501>", line 13
#     a['Team'] = a.apply(lambda x: s.replace('*', '') for s in a['Team'], axis = 1)
#                        ^
# SyntaxError: Generator expression must be parenthesized

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                a['Team'] = a.apply((lambda x: s.replace('*', '') for s in a['Team']), axis = 1)
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames)
    return result

# %%
teamPG = inputData(teamPGVars, 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-0f67ab08278e> in <module>()
# ----> 1 teamPG = inputData(teamPGVars, 1)
#
# <ipython-input-9-abb182561da9> in inputData(stats, n)
#      11                 a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
#      12             if n >= 1 and n <= 3:
# ---> 13                 a['Team'] = a.apply((lambda x: s.replace('*', '') for s in a['Team']), axis = 1)
#      14             a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
#      15         a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# TypeError: ("'generator' object is not callable", 'occurred at index 0')

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                a['Team'] = [s.replace('*', '') for s in a['Team']]
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames)
    return result

# %%
teamPG = inputData(teamPGVars, 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-0f67ab08278e> in <module>()
# ----> 1 teamPG = inputData(teamPGVars, 1)
#
# <ipython-input-11-ca827e1d5e2c> in inputData(stats, n)
#      11                 a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
#      12             if n >= 1 and n <= 3:
# ---> 13                 a['Team'] = [s.replace('*', '') for s in a['Team']]
#      14             a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
#      15         a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
#
# <ipython-input-11-ca827e1d5e2c> in <listcomp>(.0)
#      11                 a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
#      12             if n >= 1 and n <= 3:
# ---> 13                 a['Team'] = [s.replace('*', '') for s in a['Team']]
#      14             a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
#      15         a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                a['Team'] = [s.replace('*', '') for s in a['Team']]
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames)
    return result

# %%
teamPG = inputData(teamPGVars, 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-0f67ab08278e> in <module>()
# ----> 1 teamPG = inputData(teamPGVars, 1)
#
# <ipython-input-13-ca827e1d5e2c> in inputData(stats, n)
#      11                 a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
#      12             if n >= 1 and n <= 3:
# ---> 13                 a['Team'] = [s.replace('*', '') for s in a['Team']]
#      14             a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
#      15         a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
#
# <ipython-input-13-ca827e1d5e2c> in <listcomp>(.0)
#      11                 a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
#      12             if n >= 1 and n <= 3:
# ---> 13                 a['Team'] = [s.replace('*', '') for s in a['Team']]
#      14             a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
#      15         a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                a = a[0:30]
                a['Team'] = a['Team'].astype(str)
                a['Team'] = [s.replace('*', '') for s in a['Team']]
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames)
    return result

# %%
teamPG = inputData(teamPGVars, 1)
# Out:
# /Users/rohanchitale/Desktop/basketballproject/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                a = a[0:30]
                a['Team'] = a['Team'].astype(str)
                a['Team'] = [s.replace('*', '') for s in a['Team']]
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames)
    return result

# %%
teamPG = inputData(teamPGVars, 1)
# Out:
# /Users/rohanchitale/Desktop/basketballproject/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                a = a[:30]
                a['Team'] = [s.replace('*', '') for s in a['Team']]
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames)
    return result

teamPG = inputData(teamPGVars, 1)
# Out:
# /Users/rohanchitale/Desktop/basketballproject/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                a = a[:30]
                a['Team'] = [s.replace('*', '') for s in a['Team']]
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        print(a)
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames)
    return result

teamPG = inputData(teamPGVars, 1)
# Out:
#       Rk                    Team     G     MP    FG   FGA    FG%    3P   3PA  \
# 0    1.0            Phoenix Suns  82.0  240.9  41.1  81.6  0.504   6.7  17.6
# 1    2.0   Golden State Warriors  82.0  242.4  39.4  86.0  0.458   6.7  18.0
# 2    3.0      Los Angeles Lakers  82.0  241.2  40.3  85.1  0.474   6.7  18.5
# 3    4.0         New York Knicks  82.0  241.5  38.5  86.5  0.445  10.0  27.9
# 4    5.0          Indiana Pacers  82.0  241.8  39.3  86.3  0.455   8.0  21.0
# 5    6.0          Denver Nuggets  82.0  240.6  37.3  79.4  0.470   6.7  18.0
# 6    7.0               Utah Jazz  82.0  242.4  38.3  80.8  0.475   4.8  13.7
# 7    8.0           Chicago Bulls  82.0  243.0  38.1  83.5  0.457   6.0  15.8
# 8    9.0        Dallas Mavericks  82.0  241.5  38.1  82.6  0.462   7.0  19.9
# 9   10.0           Orlando Magic  82.0  240.6  35.7  78.2  0.457  10.0  26.2
# 10  11.0          Boston Celtics  82.0  242.4  37.5  77.2  0.486   6.6  16.5
# 11  12.0        Sacramento Kings  82.0  242.7  36.5  81.5  0.447   7.1  19.4
# 12  13.0     Cleveland Cavaliers  82.0  241.2  36.9  78.7  0.468   8.0  20.4
# 13  14.0  Portland Trail Blazers  82.0  241.8  36.8  79.2  0.465   7.3  19.0
# 14  15.0         Milwaukee Bucks  82.0  241.2  36.7  82.4  0.445   6.2  17.2
# 15  16.0         Toronto Raptors  82.0  241.5  37.2  81.4  0.458   5.8  15.7
# 16  17.0         Houston Rockets  82.0  241.5  36.1  79.6  0.453   7.6  20.2
# 17  18.0              Miami Heat  82.0  243.4  37.0  81.0  0.457   7.1  19.9
# 18  19.0           Atlanta Hawks  82.0  240.3  36.0  78.7  0.458   7.3  19.9
# 19  20.0         New Jersey Nets  82.0  241.8  35.7  79.7  0.448   8.0  21.2
# 29  24.0  0.375  ...   31.4  40.9  21.6  7.8  4.1  13.7  20.0   98.8\  SAC
#
#     TMYR
# 0   GSW9
# 1   HOU9
# 2   NOP9
# 3   TOR9
# 4   CLE9
# 5   DEN9
# 6   PHI9
# 7   MIN9
# 8   LAC9
# 9   CHO9
# 10  LAL9
# 11  OKC9
# 12  WAS9
# 13  BRK9
# 14  MIL9
# 15  POR9
# 16  IND9
# 17  NYK9
# 18  UTA9
# 19  BOS9
# 20  PHO9
# 21  DET9
# 22  MIA9
# 23  ORL9
# 24  ATL9
# 25  CHI9
# 26  SAS9
# 27  DAL9
# 28  MEM9
# 29  SAC9
#
# [30 rows x 27 columns]
# /Users/rohanchitale/Desktop/basketballproject/my_env/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                a = a[:30]
                a['Team'] = [s.replace('*', '') for s in a['Team']]
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        #print(a)
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames, sort = False)
    return result

teamPG = inputData(teamPGVars, 1)
print(teamPG)
# Out:
#       Rk                    Team     G     MP    FG   FGA    FG%    3P   3PA  \
# 0    1.0            Phoenix Suns  82.0  240.9  41.1  81.6  0.504   6.7  17.6
# 1    2.0   Golden State Warriors  82.0  242.4  39.4  86.0  0.458   6.7  18.0
# 2    3.0      Los Angeles Lakers  82.0  241.2  40.3  85.1  0.474   6.7  18.5
# 3    4.0         New York Knicks  82.0  241.5  38.5  86.5  0.445  10.0  27.9
# 4    5.0          Indiana Pacers  82.0  241.8  39.3  86.3  0.455   8.0  21.0
# 5    6.0          Denver Nuggets  82.0  240.6  37.3  79.4  0.470   6.7  18.0
# 6    7.0               Utah Jazz  82.0  242.4  38.3  80.8  0.475   4.8  13.7
# 7    8.0           Chicago Bulls  82.0  243.0  38.1  83.5  0.457   6.0  15.8
# 8    9.0        Dallas Mavericks  82.0  241.5  38.1  82.6  0.462   7.0  19.9
# 9   10.0           Orlando Magic  82.0  240.6  35.7  78.2  0.457  10.0  26.2
# 10  11.0          Boston Celtics  82.0  242.4  37.5  77.2  0.486   6.6  16.5
# 11  12.0        Sacramento Kings  82.0  242.7  36.5  81.5  0.447   7.1  19.4
# 12  13.0     Cleveland Cavaliers  82.0  241.2  36.9  78.7  0.468   8.0  20.4
# 13  14.0  Portland Trail Blazers  82.0  241.8  36.8  79.2  0.465   7.3  19.0
# 14  15.0         Milwaukee Bucks  82.0  241.2  36.7  82.4  0.445   6.2  17.2
# 15  16.0         Toronto Raptors  82.0  241.5  37.2  81.4  0.458   5.8  15.7
# 16  17.0         Houston Rockets  82.0  241.5  36.1  79.6  0.453   7.6  20.2
# 17  18.0              Miami Heat  82.0  243.4  37.0  81.0  0.457   7.1  19.9
# 24  0.360   ...    23.7  7.8  4.2  15.6  19.6    NaN  ATL  ATL9          25
# 25  0.355   ...    23.5  7.6  3.5  14.0  19.2    NaN  CHI  CHI9          26
# 26  0.352   ...    22.8  7.7  5.6  13.1  17.2    NaN  SAS  SAS9          27
# 27  0.360   ...    22.7  7.0  3.8  12.3  19.2    NaN  DAL  DAL9          28
# 28  0.352   ...    21.5  7.5  4.8  15.0  23.2    NaN  MEM  MEM9          29
# 29  0.375   ...    21.6  7.8  4.1  13.7  20.0    NaN  SAC  SAC9          30
#
#       PTS\
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# ..     ...
# 0   113.5\
# 1   112.4\
# 2   111.7\
# 3   111.7\
# 4   110.9\
# 5   110.0\
# 6   109.8\
# 7   109.5\
# 8   109.0\
# 9   108.2\
# 10  108.1\
# 11  107.9\
# 12  106.6\
# 13  106.6\
# 14  106.5\
# 15  105.6\
# 16  105.6\
# 17  104.5\
# 18  104.1\
# 19  104.0\
# 20  103.9\
# 21  103.8\
# 22  103.4\
# 23  103.4\
# 24  103.4\
# 25  102.9\
# 26  102.7\
# 27  102.3\
# 28   99.3\
# 29   98.8\
#
# [300 rows x 29 columns]

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                if 'PTS\\' in a
                    a['PTS'] = a['PTS\\']
                    a = a.drop(['PTS\\'], axis = 1)
                a = a[:30]
                a['Team'] = [s.replace('*', '') for s in a['Team']]
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        #print(a)
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames, sort = False)
    return result

teamPG = inputData(teamPGVars, 1)
teamPG.to_csv('TEST.csv')
# Out:
#   File "<ipython-input-22-b76bfb3363a0>", line 13
#     if 'PTS\\' in a
#                    ^
# SyntaxError: invalid syntax

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                if 'PTS\\' in a:
                    a['PTS'] = a['PTS\\']
                    a = a.drop(['PTS\\'], axis = 1)
                if 'Rk' in a:
                    a = a.drop(['Rk'], axis = 1)
                a = a[:30]
                a['Team'] = [s.replace('*', '') for s in a['Team']]
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        #print(a)
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames, sort = False)
    return result

teamPG = inputData(teamPGVars, 1)
teamPG.to_csv('TEST.csv')

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                if 'PTS\\' in a:
                    a['PTS'] = a['PTS\\']
                    a = a.drop(['PTS\\'], axis = 1)
                a = a[:30]
                a['Team'] = [s.replace('*', '') for s in a['Team']]
                a['PTS'] = [s.replace('\\', '') for s in a['PTS']]
                a['PTS'] = a['PTS'].astype(float)
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        #print(a)
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames, sort = False)
    return result

teamPG = inputData(teamPGVars, 1)
teamPG.to_csv('TEST.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-2e36348a9a6e> in <module>()
#      28     return result
#      29
# ---> 30 teamPG = inputData(teamPGVars, 1)
#      31 teamPG.to_csv('TEST.csv')
#
# <ipython-input-24-2e36348a9a6e> in inputData(stats, n)
#      16                 a = a[:30]
#      17                 a['Team'] = [s.replace('*', '') for s in a['Team']]
# ---> 18                 a['PTS'] = [s.replace('\\', '') for s in a['PTS']]
#      19                 a['PTS'] = a['PTS'].astype(float)
#      20             a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
#
# <ipython-input-24-2e36348a9a6e> in <listcomp>(.0)
#      16                 a = a[:30]
#      17                 a['Team'] = [s.replace('*', '') for s in a['Team']]
# ---> 18                 a['PTS'] = [s.replace('\\', '') for s in a['PTS']]
#      19                 a['PTS'] = a['PTS'].astype(float)
#      20             a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                if 'PTS\\' in a:
                    a['PTS'] = a['PTS\\']
                    a = a.drop(['PTS\\'], axis = 1)
                a = a[:30]
                a['Team'] = [s.replace('*', '') for s in a['Team']]
                a['PTS'] = [s.replace('\\', '') for s in a['PTS']]
                a['PTS'] = a['PTS'].astype(float)
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        #print(a)
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames, sort = False)
    return result

teamPG = inputData(teamPGVars, 1)
teamPG.to_csv('TEST.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-2e36348a9a6e> in <module>()
#      28     return result
#      29
# ---> 30 teamPG = inputData(teamPGVars, 1)
#      31 teamPG.to_csv('TEST.csv')
#
# <ipython-input-25-2e36348a9a6e> in inputData(stats, n)
#      16                 a = a[:30]
#      17                 a['Team'] = [s.replace('*', '') for s in a['Team']]
# ---> 18                 a['PTS'] = [s.replace('\\', '') for s in a['PTS']]
#      19                 a['PTS'] = a['PTS'].astype(float)
#      20             a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
#
# <ipython-input-25-2e36348a9a6e> in <listcomp>(.0)
#      16                 a = a[:30]
#      17                 a['Team'] = [s.replace('*', '') for s in a['Team']]
# ---> 18                 a['PTS'] = [s.replace('\\', '') for s in a['PTS']]
#      19                 a['PTS'] = a['PTS'].astype(float)
#      20             a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                if 'PTS\\' in a:
                    a['PTS'] = a['PTS\\']
                    a = a.drop(['PTS\\'], axis = 1)
                a = a[:30]
                a['Team'] = [s.replace('*', '') for s in a['Team']]
                a['PTS'] = a['PTS'].astype(str)
                a['PTS'] = [s.replace('\\', '') for s in a['PTS']]
                a['PTS'] = a['PTS'].astype(float)
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        #print(a)
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames, sort = False)
    return result

teamPG = inputData(teamPGVars, 1)
teamPG.to_csv('TEST.csv')

# %%
teams = inputData(teamVars, 0)

# %%
result = pd.merge(teams, teamPG, on = 'TMYR')

# %%
result['W'] = result['W'].astype(int)

# %%
print(result)
# Out:
#      TMYR   W    Rk                    Team     G     MP    FG   FGA    FG%  \
# 0    CLE0  66  13.0     Cleveland Cavaliers  82.0  241.2  36.9  78.7  0.468
# 1    BOS0  62  11.0          Boston Celtics  82.0  242.4  37.5  77.2  0.486
# 2    LAL0  65   3.0      Los Angeles Lakers  82.0  241.2  40.3  85.1  0.474
# 3    ORL0  59  10.0           Orlando Magic  82.0  240.6  35.7  78.2  0.457
# 4    POR0  54  14.0  Portland Trail Blazers  82.0  241.8  36.8  79.2  0.465
# 5    HOU0  53  17.0         Houston Rockets  82.0  241.5  36.1  79.6  0.453
# 6    SAS0  54  23.0       San Antonio Spurs  82.0  242.7  37.1  79.7  0.466
# 7    DEN0  54   6.0          Denver Nuggets  82.0  240.6  37.3  79.4  0.470
# 8    UTA0  48   7.0               Utah Jazz  82.0  242.4  38.3  80.8  0.475
# 9    ATL0  47  19.0           Atlanta Hawks  82.0  240.3  36.0  78.7  0.458
# 10   DAL0  50   9.0        Dallas Mavericks  82.0  241.5  38.1  82.6  0.462
# 11   PHO0  46   1.0            Phoenix Suns  82.0  240.9  41.1  81.6  0.504
# 12   NOH0  49  26.0     New Orleans Hornets  82.0  240.9  35.5  77.6  0.457
# 13   MIA0  43  18.0              Miami Heat  82.0  243.4  37.0  81.0  0.457
# 14   PHI0  41  22.0      Philadelphia 76ers  82.0  240.9  36.5  79.7  0.459
# 15   CHI0  41   8.0           Chicago Bulls  82.0  243.0  38.1  83.5  0.457
# 16   DET0  39  28.0         Detroit Pistons  82.0  242.7  36.4  80.0  0.454
# 17   IND0  36   5.0          Indiana Pacers  82.0  241.8  39.3  86.3  0.455
# 18   MIL0  34  15.0         Milwaukee Bucks  82.0  241.2  36.7  82.4  0.445
# 19   CHA0  35  30.0       Charlotte Bobcats  82.0  243.0  35.0  76.8  0.455
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# ..          ...
# 270           2
# 271           4
# 272           1
# 273          19
# 274           7
# 275          12
# 276          20
# 277          27
# 278          16
# 279           8
# 280           6
# 281           3
# 282          17
# 283           5
# 284          13
# 285          23
# 286           9
# 287          10
# 288          22
# 289          15
# 290          11
# 291          28
# 292          18
# 293          14
# 294          24
# 295          25
# 296          29
# 297          26
# 298          30
# 299          21
#
# [300 rows x 29 columns]

# %%
result.corr()['W']
# Out:
# W      1.000000
# Rk    -0.507502
# G      0.187037
# MP     0.023232
# FG     0.403815
# FGA   -0.129518
# FG%    0.663718
# 3P     0.321713
# 3PA    0.225039
# 3P%    0.542373
# 2P     0.018201
# 2PA   -0.344242
# 2P%    0.629014
# FT     0.218579
# FTA    0.171919
# FT%    0.151959
# ORB   -0.191337
# DRB    0.382514
# TRB    0.251481
# AST    0.373599
# STL    0.190597
# BLK    0.251614
# TOV   -0.283452
# PF    -0.202399
# PTS    0.485912
# Name: W, dtype: float64

# %%
# %matplotlib inline

# %%
result.plot.scatter(x = 'FG%', y = 'W')

# %%
for col in result.columns
    result.plot.scatter(x = col , y = 'W')
# Out:
#   File "<ipython-input-34-403285ba26fc>", line 1
#     for col in result.columns
#                              ^
# SyntaxError: invalid syntax

# %%
for col in result.columns:
    col = col.astype(float)
    result.plot.scatter(x = col , y = 'W')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-c3c474a169ed> in <module>()
#       1 for col in result.columns:
# ----> 2     col = col.astype(float)
#       3     result.plot.scatter(x = col , y = 'W')
#
# AttributeError: 'str' object has no attribute 'astype'

# %%
for col in result.columns:
    result.plot.scatter(x = col , y = 'W')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-b88e9251706b> in <module>()
#       1 for col in result.columns:
# ----> 2     result.plot.scatter(x = col , y = 'W')
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwds)
#    3459             ...                       colormap='viridis')
#    3460         """
# -> 3461         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3462
#    3463     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1741         if isinstance(data, ABCDataFrame):
#    1742             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1743                              kind=kind, **kwds)
#    1744         else:
#    1745             raise ValueError("plot kind %r can only be used for data frames"
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/plotting/_core.py in __init__(self, data, x, y, s, c, **kwargs)
#     843             # the handling of this argument later
#     844             s = 20
# --> 845         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     846         if is_integer(c) and not self.data.columns.holds_integer():
#     847             c = self.data.columns[c]
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/plotting/_core.py in __init__(self, data, x, y, **kwargs)
#     818             y = self.data.columns[y]
#     819         if len(self.data[x]._get_numeric_data()) == 0:
# --> 820             raise ValueError(self._kind + ' requires x column to be numeric')
#     821         if len(self.data[y]._get_numeric_data()) == 0:
#     822             raise ValueError(self._kind + ' requires y column to be numeric')
#
# ValueError: scatter requires x column to be numeric

# %%
for col in result.columns:
    if(result.col.dtype == float):
        result.plot.scatter(x = col , y = 'W')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-ffe2e25566b1> in <module>()
#       1 for col in result.columns:
# ----> 2     if(result.col.dtype == float):
#       3         result.plot.scatter(x = col , y = 'W')
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'col'

# %%
for col in result.columns:
    result[col] = result[col].astype(float)
    result.plot.scatter(x = col , y = 'W')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-4c246b21a1f8> in <module>()
#       1 for col in result.columns:
# ----> 2     result[col] = result[col].astype(float)
#       3     result.plot.scatter(x = col , y = 'W')
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    3712
#    3713     def astype(self, dtype, **kwargs):
# -> 3714         return self.apply('astype', dtype=dtype, **kwargs)
#    3715
#    3716     def convert(self, **kwargs):
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     573     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     574         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 575                             **kwargs)
#     576
#     577     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     662
#     663                 # _astype_nansafe works fine with 1-d only
# --> 664                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     665                 values = values.reshape(self.shape)
#     666
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy)
#     728
#     729     if copy:
# --> 730         return arr.astype(dtype, copy=True)
#     731     return arr.view(dtype)
#     732
#
# ValueError: could not convert string to float: 'PHO9'

# %%
oTeamPG = ['oTeamPG09.csv', 'oTeamPG10.csv', 'oTeamPG11.csv', 'oTeamPG12.csv', 'oTeamPG13.csv' , 'oTeamPG14.csv' , 'oTeamPG15.csv' , 'oTeamPG16.csv', 'oTeamPG17.csv', 'oTeamPG18.csv']

# %%
oTeamPGs = inputData(oTeamPG, 2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tm'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in set(self, item, value, check)
#    4242         try:
# -> 4243             loc = self.items.get_loc(item)
#    4244         except KeyError:
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tm'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-df3bbfe2a93c> in <module>()
# ----> 1 oTeamPGs = inputData(oTeamPG, 2)
#
# <ipython-input-26-45adf4af412c> in inputData(stats, n)
#      19                 a['PTS'] = [s.replace('\\', '') for s in a['PTS']]
#      20                 a['PTS'] = a['PTS'].astype(float)
# ---> 21             a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
#      22         a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
#      23         if n == 0:
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3193         self._ensure_valid_index(value)
#    3194         value = self._sanitize_column(key, value)
# -> 3195         NDFrame._set_item(self, key, value)
#    3196
#    3197         # check if we are modifying a copy
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/generic.py in _set_item(self, key, value)
#    2598
#    2599     def _set_item(self, key, value):
# -> 2600         self._data.set(key, value)
#    2601         self._clear_item_cache()
#    2602
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in set(self, item, value, check)
#    4244         except KeyError:
#    4245             # This item wasn't present, just insert at end
# -> 4246             self.insert(len(self.items), item, value)
#    4247             return
#    4248
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in insert(self, loc, item, value, allow_duplicates)
#    4345
#    4346         block = make_block(values=value, ndim=self.ndim,
# -> 4347                            placement=slice(loc, loc + 1))
#    4348
#    4349         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3203                      placement=placement, dtype=dtype)
#    3204
# -> 3205     return klass(values, ndim=ndim, placement=placement)
#    3206
#    3207 # TODO: flexible with index=None and/or items=None
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim)
#    2301
#    2302         super(ObjectBlock, self).__init__(values, ndim=ndim,
# -> 2303                                           placement=placement)
#    2304
#    2305     @property
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim)
#     123             raise ValueError(
#     124                 'Wrong number of items passed {val}, placement implies '
# --> 125                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#     126
#     127     def _check_ndim(self, values, ndim):
#
# ValueError: Wrong number of items passed 300, placement implies 1

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                if 'PTS\\' in a:
                    a['PTS'] = a['PTS\\']
                    a = a.drop(['PTS\\'], axis = 1)
                a = a[:30]
                a['Team'] = [s.replace('*', '') for s in a['Team']]
                a['PTS'] = a['PTS'].astype(str)
                a['PTS'] = [s.replace('\\', '') for s in a['PTS']]
                a['PTS'] = a['PTS'].astype(float)
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        print(a)
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames, sort = False)
    return result

teamPG = inputData(teamPGVars, 1)
teamPG.to_csv('TEST.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tm'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in set(self, item, value, check)
#    4242         try:
# -> 4243             loc = self.items.get_loc(item)
#    4244         except KeyError:
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tm'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-efcb8028862c> in <module>()
#      29     return result
#      30
# ---> 31 teamPG = inputData(teamPGVars, 1)
#      32 teamPG.to_csv('TEST.csv')
#
# <ipython-input-42-efcb8028862c> in inputData(stats, n)
#      19                 a['PTS'] = [s.replace('\\', '') for s in a['PTS']]
#      20                 a['PTS'] = a['PTS'].astype(float)
# ---> 21             a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
#      22         a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
#      23         if n == 0:
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3193         self._ensure_valid_index(value)
#    3194         value = self._sanitize_column(key, value)
# -> 3195         NDFrame._set_item(self, key, value)
#    3196
#    3197         # check if we are modifying a copy
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/generic.py in _set_item(self, key, value)
#    2598
#    2599     def _set_item(self, key, value):
# -> 2600         self._data.set(key, value)
#    2601         self._clear_item_cache()
#    2602
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in set(self, item, value, check)
#    4244         except KeyError:
#    4245             # This item wasn't present, just insert at end
# -> 4246             self.insert(len(self.items), item, value)
#    4247             return
#    4248
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in insert(self, loc, item, value, allow_duplicates)
#    4345
#    4346         block = make_block(values=value, ndim=self.ndim,
# -> 4347                            placement=slice(loc, loc + 1))
#    4348
#    4349         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3203                      placement=placement, dtype=dtype)
#    3204
# -> 3205     return klass(values, ndim=ndim, placement=placement)
#    3206
#    3207 # TODO: flexible with index=None and/or items=None
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim)
#    2301
#    2302         super(ObjectBlock, self).__init__(values, ndim=ndim,
# -> 2303                                           placement=placement)
#    2304
#    2305     @property
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim)
#     123             raise ValueError(
#     124                 'Wrong number of items passed {val}, placement implies '
# --> 125                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#     126
#     127     def _check_ndim(self, values, ndim):
#
# ValueError: Wrong number of items passed 300, placement implies 1

# %%
 def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                if 'PTS\\' in a:
                    a['PTS'] = a['PTS\\']
                    a = a.drop(['PTS\\'], axis = 1)
                a = a[:30]
                a['Team'] = [s.replace('*', '') for s in a['Team']]
                a['PTS'] = a['PTS'].astype(str)
                a['PTS'] = [s.replace('\\', '') for s in a['PTS']]
                a['PTS'] = a['PTS'].astype(float)
                print(a)
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        print(a)
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames, sort = False)
    return result

# %%
teamPG = inputData(teamPGVars, 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tm'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in set(self, item, value, check)
#    4242         try:
# -> 4243             loc = self.items.get_loc(item)
#    4244         except KeyError:
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tm'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-0f67ab08278e> in <module>()
# ----> 1 teamPG = inputData(teamPGVars, 1)
#
# <ipython-input-43-a37f9e25c5d8> in inputData(stats, n)
#      19                a['PTS'] = [s.replace('\\', '') for s in a['PTS']]
#      20                a['PTS'] = a['PTS'].astype(float)
# ---> 21            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
#      22        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
#      23        if n == 0:
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3193         self._ensure_valid_index(value)
#    3194         value = self._sanitize_column(key, value)
# -> 3195         NDFrame._set_item(self, key, value)
#    3196
#    3197         # check if we are modifying a copy
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/generic.py in _set_item(self, key, value)
#    2598
#    2599     def _set_item(self, key, value):
# -> 2600         self._data.set(key, value)
#    2601         self._clear_item_cache()
#    2602
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in set(self, item, value, check)
#    4244         except KeyError:
#    4245             # This item wasn't present, just insert at end
# -> 4246             self.insert(len(self.items), item, value)
#    4247             return
#    4248
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in insert(self, loc, item, value, allow_duplicates)
#    4345
#    4346         block = make_block(values=value, ndim=self.ndim,
# -> 4347                            placement=slice(loc, loc + 1))
#    4348
#    4349         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3203                      placement=placement, dtype=dtype)
#    3204
# -> 3205     return klass(values, ndim=ndim, placement=placement)
#    3206
#    3207 # TODO: flexible with index=None and/or items=None
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim)
#    2301
#    2302         super(ObjectBlock, self).__init__(values, ndim=ndim,
# -> 2303                                           placement=placement)
#    2304
#    2305     @property
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim)
#     123             raise ValueError(
#     124                 'Wrong number of items passed {val}, placement implies '
# --> 125                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#     126
#     127     def _check_ndim(self, values, ndim):
#
# ValueError: Wrong number of items passed 300, placement implies 1

# %%
def inputData(stats, n): # n = 0 - team rankings, 1 - team per game stats
                        # 2 - opponent per game stats, 3 - misc stats
    createDict()
    counter = 0
    frames = []
    for item in stats:
        a = pd.read_csv(item)
        if n >= 0 and n <= 3:
            if n == 0:  #delete first row of team rankings dataframe
                a = a.iloc[1:, 0:5]        
                a.columns = ['Rk', 'Team', 'Conf', 'Div', 'W']
            if n >= 1 and n <= 3:
                if 'PTS\\' in a:
                    a['PTS'] = a['PTS\\']
                    a = a.drop(['PTS\\'], axis = 1)
                a = a[:30]
                a['Team'] = [s.replace('*', '') for s in a['Team']]
                a['PTS'] = a['PTS'].astype(str)
                a['PTS'] = [s.replace('\\', '') for s in a['PTS']]
                a['PTS'] = a['PTS'].astype(float)
                print(a)
            a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
        a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
        if n == 0:
            a = a[["TMYR", "W"]]
        print(a)
        counter = counter + 1;
        frames.append(a)
    result = pd.concat(frames, sort = False)
    return result

# %%
teamPG = inputData(teamPGVars, 1)
# Out:
#       Rk                    Team     G     MP    FG   FGA    FG%    3P   3PA  \
# 0    1.0            Phoenix Suns  82.0  240.9  41.1  81.6  0.504   6.7  17.6
# 1    2.0   Golden State Warriors  82.0  242.4  39.4  86.0  0.458   6.7  18.0
# 2    3.0      Los Angeles Lakers  82.0  241.2  40.3  85.1  0.474   6.7  18.5
# 3    4.0         New York Knicks  82.0  241.5  38.5  86.5  0.445  10.0  27.9
# 4    5.0          Indiana Pacers  82.0  241.8  39.3  86.3  0.455   8.0  21.0
# 5    6.0          Denver Nuggets  82.0  240.6  37.3  79.4  0.470   6.7  18.0
# 6    7.0               Utah Jazz  82.0  242.4  38.3  80.8  0.475   4.8  13.7
# 7    8.0           Chicago Bulls  82.0  243.0  38.1  83.5  0.457   6.0  15.8
# 8    9.0        Dallas Mavericks  82.0  241.5  38.1  82.6  0.462   7.0  19.9
# 9   10.0           Orlando Magic  82.0  240.6  35.7  78.2  0.457  10.0  26.2
# 10  11.0          Boston Celtics  82.0  242.4  37.5  77.2  0.486   6.6  16.5
# 11  12.0        Sacramento Kings  82.0  242.7  36.5  81.5  0.447   7.1  19.4
# 12  13.0     Cleveland Cavaliers  82.0  241.2  36.9  78.7  0.468   8.0  20.4
# 13  14.0  Portland Trail Blazers  82.0  241.8  36.8  79.2  0.465   7.3  19.0
# 14  15.0         Milwaukee Bucks  82.0  241.2  36.7  82.4  0.445   6.2  17.2
# 15  0.372  ...    0.824   9.8  30.6  40.4  22.4  6.4  4.8  13.4  19.4   99.0
# 16  0.375  ...    0.805  10.5  32.5  43.0  20.3  6.7  4.3  14.1  18.9   98.4
# 17  0.357  ...    0.754  10.1  29.4  39.5  20.4  7.9  5.5  12.5  20.7   98.3
# 18  0.366  ...    0.737  10.6  29.4  40.0  20.2  7.4  4.6  12.8  19.6   98.1
# 19  0.376  ...    0.779  10.4  29.5  39.8  20.0  6.8  4.8  13.1  22.4   98.1
# 20  0.353  ...    0.769  11.9  29.8  41.7  20.4  6.2  3.9  14.2  21.8   97.8
# 21  0.318  ...    0.745  12.7  28.5  41.2  20.1  8.0  5.1  14.1  20.1   97.4
# 22  0.386  ...    0.761   8.9  32.2  41.0  21.2  5.8  4.0  11.7  18.9   97.0
# 23  0.346  ...    0.786  12.2  30.5  42.6  20.3  7.4  4.5  16.2  20.2   97.0
# 24  0.330  ...    0.767  11.7  28.4  40.1  20.0  7.5  4.5  14.0  20.5   96.1
# 25  0.364  ...    0.807   9.8  29.9  39.7  19.6  7.2  4.1  12.5  20.3   95.8
# 26  0.354  ...    0.736  10.9  29.0  39.8  21.0  7.0  5.9  14.9  20.1   95.1
# 27  0.349  ...    0.751  11.6  29.9  41.4  20.6  6.0  4.6  11.9  20.9   94.2
# 28  0.360  ...    0.756  10.3  28.5  38.8  17.4  7.5  4.7  15.3  21.7   93.9
# 29  0.366  ...    0.740  10.8  28.9  39.7  21.2  7.1  4.8  15.6  21.4   93.6
#
# [30 rows x 25 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tm'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in set(self, item, value, check)
#    4242         try:
# -> 4243             loc = self.items.get_loc(item)
#    4244         except KeyError:
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tm'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-0f67ab08278e> in <module>()
# ----> 1 teamPG = inputData(teamPGVars, 1)
#
# <ipython-input-46-ed5df6d09daf> in inputData(stats, n)
#      20                 a['PTS'] = a['PTS'].astype(float)
#      21                 print(a)
# ---> 22             a['Tm'] = a.apply(lambda x: teams[str(x.Team)], axis = 1)
#      23         a["TMYR"] = a.apply(lambda x: str(x.Tm) + str(counter), axis = 1)
#      24         if n == 0:
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3193         self._ensure_valid_index(value)
#    3194         value = self._sanitize_column(key, value)
# -> 3195         NDFrame._set_item(self, key, value)
#    3196
#    3197         # check if we are modifying a copy
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/generic.py in _set_item(self, key, value)
#    2598
#    2599     def _set_item(self, key, value):
# -> 2600         self._data.set(key, value)
#    2601         self._clear_item_cache()
#    2602
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in set(self, item, value, check)
#    4244         except KeyError:
#    4245             # This item wasn't present, just insert at end
# -> 4246             self.insert(len(self.items), item, value)
#    4247             return
#    4248
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in insert(self, loc, item, value, allow_duplicates)
#    4345
#    4346         block = make_block(values=value, ndim=self.ndim,
# -> 4347                            placement=slice(loc, loc + 1))
#    4348
#    4349         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3203                      placement=placement, dtype=dtype)
#    3204
# -> 3205     return klass(values, ndim=ndim, placement=placement)
#    3206
#    3207 # TODO: flexible with index=None and/or items=None
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim)
#    2301
#    2302         super(ObjectBlock, self).__init__(values, ndim=ndim,
# -> 2303                                           placement=placement)
#    2304
#    2305     @property
#
# ~/Desktop/basketballproject/my_env/lib/python3.7/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim)
#     123             raise ValueError(
#     124                 'Wrong number of items passed {val}, placement implies '
# --> 125                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#     126
#     127     def _check_ndim(self, values, ndim):
#
# ValueError: Wrong number of items passed 300, placement implies 1
